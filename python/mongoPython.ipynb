# %% [markdown]
# Creare un database con MongoDB
# https://www.mongodb.com/
# https://cloud.mongodb.com/ -> Mongo DB Cloud
# https://www.mongodb.com/it-it/resources/languages/python
# https://www.mongodb.com/docs/manual/tutorial/query-documents/
#
# Scaricare ed installare Compass per la gestione del DB Mongo in locale
#
# Tramite PIP installare PyMongo
# pip install pymongo

# %%
import pymongo

# Leggo il cluster del mio DB Mongo tramite la stringa di connessione
cluster = pymongo.MongoClient("mongodb+srv://admin:root@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
# print(cluster)
# Leggo una lista di database presente nel cluster
dbList = cluster.list_database_names()
print(dbList)
# Controlle se nel cluster è presente un database di nome DataMongoPython
if "DataMongoPython" in dbList:
    print("DataMongoPython collection exists!!!")
    # assegno alla variabile database il database di nome DataMongoPython presente nel cluster
    database = cluster.DataMongoPython
    # assegno alla variabile users la collection users presente nel database DataMongoPython
    users = database["users"]
    # print(users)
    
# Eliminare un database ATTENZIONE!!!!
# users.drop()

# %%
import pymongo
connectionString = "mongodb+srv://admin:root@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

cluster = pymongo.MongoClient(connectionString)
database = cluster.DataMongoPython
users = database['users']

# Creare un dato nella collection -> INSERT di sql

# Per inserire un record in MongoDB, utilizziamo il metodo insert_one()
# Il metodo insert_one() restituisce un oggetto di tipo InsertOneResult,
# che ha una proprietà di nome inserted_id che contiene il valore id
# dell'oggetto inserito nella collection
dict = { "name": "Giuseppe", 
         "lastname": "Verdi", 
         "city": "Milano", 
         "age": 23 }
# result =  users.insert_one(dict)
# if result.inserted_id :
#    print(result.inserted_id, " created!!!")

# Inserisco più record nel database
# Per inserire più di un dizionari in una collection MongoDB
# utilizziamo il metodo insert_many()
# Il metodo insert_many() restituisce un oggetto di tipo InsertManyResult,
# che ha una proprietà di nome inserted_ids che contiene i valori id
# degli oggetti inseriti nella collection
list = [
    {"name": "Francesca", "lastname": "Neri", "city": "Napoli", "age": 22},
    {"name": "Antonio", "lastname": "Bianchi", "city": "Torino", "age": 56},
    {"name": "Viola", "lastname": "Viola", "city": "Palermo", "age": 31}
]
    
result =  users.insert_many(list)
if result.inserted_ids :
    print(result.inserted_ids, " created!!!")

# %%
import pymongo
connectionString = "mongodb+srv://admin:root@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

cluster = pymongo.MongoClient(connectionString)
database = cluster.DataMongoPython
users = database['users']

# Leggere un dato nella collection -> SELECT di sql
# Per leggere dati da una raccolta in mongoDB, possiamo utilizzare
# il metodo find_one(). 
# Restituisce la prima occorrenza della selezione
obj = users.find_one()
print(obj )
print(obj['name'], obj['lastname'])

# Per leggere tutti i dati da una raccolta in mongoDB, 
# possiamo utilizzare il metodo find().
# Restituisce tutte i dati della collection
list = users.find()
print(list)
for o in list:
    # print(o)
    print(o['name'], o['lastname'])

# %%
from bson import Regex
import pymongo
connectionString = "mongodb+srv://admin:root@cluster0.7opl1ou.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

cluster = pymongo.MongoClient(connectionString)
database = cluster.DataMongoPython
users = database['users']

# Filtrare dati nella collection
# nel metodo find[find_one] il primo parametro è un oggetto di tipo query
# possiamo utilizzarlo per filtrare i risultati della collection 
list = users.find({"city": "Roma"})
# print(list)
# for o in list:
#    print(o)

# Seleziono tutti gli oggetti in cui la proprietà city è 
# contenuta($in) in un set di valori
filterList = users.find({"city": {"$in": ["Roma", "Milano", "Napoli"]}})
# for o in filterList:
#    print(o)

# Seleziono tutti gli oggetti in cui la proprietà age è 
# maggiore($gt) di un determinato valore
filterAge = users.find({"age": {"$gt": 30}})
# for o in filterAge:
#    print(o)
    
# Seleziono tutti gli oggetti in cui la proprietà age è 
# minore($lt) di un determinato valore
filterAge = users.find({"age": {"$lt": 30}})
# for o in filterAge:
#    print(o)

# Seleziono tutti gli oggetti in cui la proprietà name AND la 
# proprietà city hanno un determinato valore
filterAnd = users.find({"name": "Mario", "city": "Roma"})
# for o in filterAnd:
#    print(o)

# Seleziono tutti gli oggetti in cui la proprietà name OR la 
# proprietà city hanno un determinato valore
filterOr = users.find({"$or": [{"name": "Giuseppe"}, {"city": "Roma"}]})
# for o in filterOr:
#    print(o)

# E' anche possibile utilizzare le espressioni regolari come filtro
# In questo esempio abbiamo selezionato tutti gli oggetti che hanno
# un cognome che comincia per V
filterRegex = users.find({"lastname": {"$regex": "^V"}})
for o in filterRegex:
    print(o)
# Out:
# {'_id': ObjectId('6704f127c338b691dadb12ab'), 'name': 'Giuseppe', 'lastname': 'Verdi', 'city': 'Milano', 'age': 23}
# {'_id': ObjectId('6704ff2cc338b691dadb12b0'), 'name': 'Viola', 'lastname': 'Viola', 'city': 'Roma', 'age': 31}

# %%
# Modificare un dato nella collection -> UPDATE di sql

# Eliminare un dato nella collection -> DELETE di sql
